# %% [markdown]
# This script performs CD test on HLCA dataset and Carraro and IPF dataset using polyEN pipeline

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
from tqdm import tqdm
from functools import reduce
from anndata import concat

# %% [markdown]
# Read HLCA and corrected combined data

# %%
hlca_smoker = sc.read_h5ad("data/step1_HLCA_smoker_processed.h5ad")
hlca_nonsmoker = sc.read_h5ad("data/step1_HLCA_nonsmoker_processed.h5ad")
# Out:
# /jet/home/qsong/.conda/envs/lung_aging/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /jet/home/qsong/.conda/envs/lung_aging/lib/python3.9/site-packages/anndata/_core/anndata.py:121: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
combined_smoker = sc.read_h5ad("results/correction_mnnpy/corrected_combined_smoker.h5ad")
combined_nonsmoker = sc.read_h5ad("results/correction_mnnpy/corrected_combined_nonsmoker.h5ad")

combined_smoker = combined_smoker[combined_smoker.obs["batch"] != "HLCA",]
combined_nonsmoker = combined_nonsmoker[combined_nonsmoker.obs["batch"] != "HLCA",]
smoker_ind = pd.Index(["-".join(ind[:-1]) for ind in combined_smoker.obs.index.str.split("-")])
nonsmoker_ind = pd.Index(["-".join(ind[:-1]) for ind in combined_nonsmoker.obs.index.str.split("-")])

combined_smoker_obs1 = sc.read_h5ad("data/step1_combined_smoker_processed.h5ad").obs
combined_nonsmoker_obs1 = sc.read_h5ad("data/step1_combined_nonsmoker_processed.h5ad").obs

# %%
combined_smoker = sc.read_h5ad("results/correction_mnnpy/corrected_combined_smoker.h5ad")
combined_nonsmoker = sc.read_h5ad("results/correction_mnnpy/corrected_combined_nonsmoker.h5ad")

combined_smoker = combined_smoker[combined_smoker.obs["batch"] != "HLCA",]
combined_nonsmoker = combined_nonsmoker[combined_nonsmoker.obs["batch"] != "HLCA",]
smoker_ind = pd.Index(["-".join(ind[:-1]) for ind in combined_smoker.obs.index.str.split("-")])
nonsmoker_ind = pd.Index(["-".join(ind[:-1]) for ind in combined_nonsmoker.obs.index.str.split("-")])

combined_smoker_obs1 = sc.read_h5ad("data/step1_combined_smoker_processed.h5ad").obs
combined_nonsmoker_obs1 = sc.read_h5ad("data/step1_combined_nonsmoker_processed.h5ad").obs

combined_smoker_obs2 = sc.read_h5ad("results/label_transfer/combined_smoker/combined_embedding.h5ad").obs
combined_nonsmoker_obs2 = sc.read_h5ad("results/label_transfer/combined_nonsmoker/combined_embedding.h5ad").obs
combined_smoker_obs2 = combined_smoker_obs2.loc[combined_smoker_obs2["batch"] == '1',]
combined_nonsmoker_obs2 = combined_nonsmoker_obs2.loc[combined_nonsmoker_obs2["batch"] == '1',]

del(combined_smoker_obs2['age'])
del(combined_nonsmoker_obs2['age'])
del(combined_smoker_obs2['dataset'])
del(combined_nonsmoker_obs2['dataset'])

combined_smoker.obs = pd.concat([combined_smoker_obs1.loc[smoker_ind,], combined_smoker_obs2.loc[smoker_ind,]],axis = 1)
combined_nonsmoker.obs = pd.concat([combined_nonsmoker_obs1.loc[nonsmoker_ind,], combined_nonsmoker_obs2.loc[nonsmoker_ind,]], axis = 1)
# Out:
# /jet/home/qsong/.conda/envs/lung_aging/lib/python3.9/site-packages/anndata/_core/anndata.py:1828: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %% [markdown]
# Keep these columns for cell meta data

# %%
hlca_smoker.obs = hlca_smoker.obs.loc[:,['donor_id',
                                       'age',
                                       'dataset',
                                       'ann_level_1',
                                       'ann_level_2',
                                       'ann_level_3',
                                       'ann_level_4',
                                       'ann_level_5']
                                     ]
hlca_nonsmoker.obs = hlca_nonsmoker.obs.loc[:,['donor_id',
                                       'age',
                                        'dataset',
                                       'ann_level_1',
                                       'ann_level_2',
                                       'ann_level_3',
                                       'ann_level_4',
                                       'ann_level_5']
                                     ]

combined_smoker.obs = combined_smoker.obs.loc[:,['donor_id',
                                       'age',
                                        'dataset',
                                       'Level_1_transfered_label',
                                       'Level_2_transfered_label',
                                       'Level_3_transfered_label',
                                       'Level_4_transfered_label',
                                       'Level_5_transfered_label']
                                      ]
combined_nonsmoker.obs = combined_nonsmoker.obs.loc[:,['donor_id',
                                       'age',
                                        'dataset',
                                       'Level_1_transfered_label',
                                       'Level_2_transfered_label',
                                       'Level_3_transfered_label',
                                       'Level_4_transfered_label',
                                       'Level_5_transfered_label']
                                      ]
combined_smoker.obs.columns = ['donor_id','age','dataset','ann_level_1','ann_level_2','ann_level_3','ann_level_4','ann_level_5']
combined_nonsmoker.obs.columns = ['donor_id','age','dataset','ann_level_1','ann_level_2','ann_level_3','ann_level_4','ann_level_5']

# %%
train_nonsmoker = hlca_nonsmoker[hlca_nonsmoker.obs['dataset'] != "Banovich_Kropski_2020",].copy()
test_nonsmoker = concat([hlca_nonsmoker[hlca_nonsmoker.obs['dataset'] == "Banovich_Kropski_2020",],
        combined_nonsmoker]
      )

train_smoker = hlca_smoker[hlca_smoker.obs['dataset'] == "Banovich_Kropski_2020",].copy()
test_smoker = concat([
         hlca_smoker[hlca_smoker.obs['dataset'] != "Banovich_Kropski_2020",],
        combined_smoker[combined_smoker.obs["dataset"] == "Kaminski",]]
      )

# %% [markdown]
# Define different types of gene sets used as input features

# %%
test_genes = {"fridman":["ALDH1A3", "AOPEP", "CCND1", "CD44", "CDKN1A", "CDKN1C", "CDKN2A", "CDKN2B", "CDKN2D", "CITED2",
                                "CLTB", "COL1A2","CREG1","CRYAB","CCN2","CXCL14","CYP1B1","EIF2S2","ESM1","F3","FILIP1L","FN1","GSN","GUK1","HBS1L",
                                "HPS5","HSPA2","HTATIP2","IFI16","IFNG","IGFBP1","IGFBP2","IGFBP3","IGFBP4","IGFBP5","IGFBP6","IGFBP7","IGSF3",
                                "ING1","IRF5","IRF7","ISG15","MAP1LC3B","MAP2K3","MDM2","MMP1","NDN","NME2","NRG1","OPTN","PEA15","RAB13","RAB31",
                                "RAB5B","RABGGTA","RAC1","RBL2","RGL2","RHOB","RRAS","S100A11","SERPINB2","SERPINE1","SMPD1","SMURF2","SOD1","SPARC",
                                "STAT1","TES","TFAP2A","TGFB1I1","THBS1","TNFAIP2","TNFAIP3","TP53","TSPYL5","VIM","ALDH1A1","BMI1","CCNB1","CDC25B",
                                "CKS1BP7","COL3A1","E2F4","EGR1","ID1","LAMA1","LDB2","MARCKS","CCN4"],
              "sasp2":["VEGFA", "TNFRSF12A", "TNFRSF10C", "TNFRSF10B", "TIMP2", "TIMP1", "TGFB1", "SERPINE1", "TNFRSF1A",
                                    "PLAUR", "PLAU", "MMP14", "MMP13", "MMP7", "MMP3", "MIF", "LMNA", "KITLG", "IL32", "IGFBP7", "IGFBP2",
                                     "ICAM1", "FAS", "EREG", "CXCL17", "CXCL16", "CXCL8", "CXCL1", "CTSB", "CLU", "CCL20", "CCL2", "BTC",
                                     "AREG"
                                  ],
              "senmayo":pd.read_excel("data/senescence_list.xlsx",sheet_name="SenMayo")["symbol"].tolist(),
              "cellage":pd.read_excel("data/senescence_list.xlsx",sheet_name="CellAge Senescence Genes")["Symbol"].tolist()
                }

test_genes["union"] = reduce(np.union1d, [test_genes["fridman"],
                    test_genes["sasp2"],
                    test_genes["senmayo"],
                    test_genes["cellage"]]
      )

# %% [markdown]
# ## Modeling

# %%
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler

from functools import partial
from hyperopt import hp, Trials, fmin, tpe
from hyperopt import space_eval

# %% [markdown]
# Data filtering by Number of Cells

# %%
'''
Filter anndata by cell type, marker genes, and subjects. Subjects are selected by min_cells
Return filtered expression matrix and ages.
'''
def filter_anndata_single_ct(anndata, ct_column, ct, donor_column, age_column, marker_genes = None, min_cells = 20):
        
    # Keep rows annotated with current cell type, and columns annotated with marker genes,  
    ct_anndata = anndata[anndata.obs[ct_column] == ct, :]
    ct_anndata = ct_anndata[:, ct_anndata.var_names.isin(marker_genes)]
    
    # Select subjects having number of cells greater than min_cells 
    subjects = ct_anndata.obs[donor_column]
    subjects_count = subjects.groupby(subjects.values).count()
    selected_subjects = subjects_count.loc[subjects_count >= min_cells].index 
    
    # Furtuer suset anndata using the selected subjects
    ct_anndata = ct_anndata[ct_anndata.obs[donor_column].isin(selected_subjects),]
    
    # Generate filtered expression matrix and ages
    expr = ct_anndata.to_df()
    expr.index = ct_anndata.obs[donor_column].values
    ages = ct_anndata.obs[age_column]
    ages.index = expr.index
        
    return expr, ages

# %% [markdown]
# keep consistent genes between two datasets

# %%
common_smoker_gene = np.intersect1d(train_smoker.var_names, test_smoker.var_names)
common_nonsmoker_gene = np.intersect1d(train_nonsmoker.var_names, test_nonsmoker.var_names)

# %%
train_smoker = train_smoker[:,common_smoker_gene]
train_nonsmoker = train_nonsmoker[:,common_nonsmoker_gene]
test_smoker = test_smoker[:,common_smoker_gene]
test_nonsmoker = test_nonsmoker[:,common_nonsmoker_gene]

# %%
test_genes["common_smoker"] = common_smoker_gene
test_genes["common_nonsmoker"] = common_nonsmoker_gene

# %% [markdown]
# Genearte data

# %%
import warnings
warnings.filterwarnings("ignore")

groups = ["smoker","nonsmoker"]
train_data = [train_smoker,train_nonsmoker]
test_data = [test_smoker,test_nonsmoker]
annLevels = ['ann_level_2', 'ann_level_3', 'ann_level_4', 'ann_level_5']
gene_types = test_genes.keys()
n_rep = 5
iterator = []

for adata_train,adata_test,group in zip(train_data,test_data,groups):
    for annLevel in annLevels:
        
        cts1 = adata_train.obs[annLevel].unique().tolist()
        cts2 = adata_test.obs[annLevel].unique().tolist()
        cell_types = np.intersect1d(cts1,cts2)
        cell_types = cell_types[cell_types != "None"]
        for ct in cell_types:
            gene_types = ['fridman', 'sasp2', 'senmayo', 'cellage','union',f'common_{group}'
                         ]
            
            for gene_type in gene_types:
                
                # Get donor number for train data
                adata_ct = adata_train[adata_train.obs[annLevel] == ct,]
                expr_train,ages_train = filter_anndata_single_ct(adata_ct,
                                         ct_column = annLevel,
                                         ct = ct,
                                         donor_column = "donor_id",
                                         age_column = "age",
                                         marker_genes = np.intersect1d(test_genes[gene_type],adata_ct.var_names),
                                         min_cells = 20
                                        )
                donor_num_train = expr_train.index.unique().shape[0]
                age_train_mean = ages_train.groupby(ages_train).mean().mean()
                age_train_std = ages_train.groupby(ages_train).mean().std()
                del(adata_ct)
                
                # Get donor number for test data
                adata_ct = adata_test[adata_test.obs[annLevel] == ct,]
                expr_test,ages_test = filter_anndata_single_ct(adata_ct,
                                         ct_column = annLevel,
                                         ct = ct,
                                         donor_column = "donor_id",
                                         age_column = "age",
                                         marker_genes = np.intersect1d(test_genes[gene_type],adata_ct.var_names),
                                         min_cells = 20
                                        )
                    
                donor_num_test = expr_test.index.unique().shape[0]
                age_test_mean = ages_test.groupby(ages_test).mean().mean()
                age_test_std = ages_test.groupby(ages_test).mean().std()
                del(adata_ct)


                #if donor_num_train >= 5 and donor_num_test >= 5 and ct != "None":
                for use_pca in [True,False]:
                    for rep in range(1,n_rep+1):
                          iterator.append([expr_train,ages_train,
                                       expr_test,ages_test,
                                       group,ct,annLevel,gene_type,
                                       use_pca,rep,donor_num_train,donor_num_test]
                                     )
                print(group,annLevel,ct,gene_type,"done")
# Out:
# smoker ann_level_2 Airway epithelium fridman done
# smoker ann_level_2 Airway epithelium sasp2 done
# smoker ann_level_2 Airway epithelium senmayo done
# smoker ann_level_2 Airway epithelium cellage done
# smoker ann_level_2 Airway epithelium union done
# smoker ann_level_2 Airway epithelium common_smoker done
# smoker ann_level_2 Alveolar epithelium fridman done
# smoker ann_level_2 Alveolar epithelium sasp2 done
# smoker ann_level_2 Alveolar epithelium senmayo done
# smoker ann_level_2 Alveolar epithelium cellage done
# smoker ann_level_2 Alveolar epithelium union done
# smoker ann_level_2 Alveolar epithelium common_smoker done
# smoker ann_level_2 Blood vessels fridman done
# smoker ann_level_2 Blood vessels sasp2 done
# smoker ann_level_2 Blood vessels senmayo done
# smoker ann_level_2 Blood vessels cellage done
# smoker ann_level_2 Blood vessels union done
# smoker ann_level_2 Blood vessels common_smoker done
# smoker ann_level_2 Fibroblast lineage fridman done
# smoker ann_level_2 Fibroblast lineage sasp2 done
# smoker ann_level_2 Fibroblast lineage senmayo done
# smoker ann_level_2 Fibroblast lineage cellage done
# smoker ann_level_2 Fibroblast lineage union done
# smoker ann_level_2 Fibroblast lineage common_smoker done
# smoker ann_level_2 Hematopoietic stem cells fridman done
# smoker ann_level_2 Hematopoietic stem cells sasp2 done
# smoker ann_level_2 Hematopoietic stem cells senmayo done
# smoker ann_level_2 Hematopoietic stem cells cellage done
# smoker ann_level_2 Hematopoietic stem cells union done
# smoker ann_level_2 Hematopoietic stem cells common_smoker done
# smoker ann_level_2 Lymphatic EC fridman done
# smoker ann_level_2 Lymphatic EC sasp2 done
# smoker ann_level_2 Lymphatic EC senmayo done
# smoker ann_level_2 Lymphatic EC cellage done
# smoker ann_level_2 Lymphatic EC union done
# smoker ann_level_2 Lymphatic EC common_smoker done
# smoker ann_level_2 Lymphoid fridman done
# smoker ann_level_2 Lymphoid sasp2 done
# smoker ann_level_2 Lymphoid senmayo done
# smoker ann_level_2 Lymphoid cellage done
# smoker ann_level_2 Lymphoid union done
# smoker ann_level_2 Lymphoid common_smoker done
# smoker ann_level_2 Mesothelium fridman done
# smoker ann_level_2 Mesothelium sasp2 done
# smoker ann_level_2 Mesothelium senmayo done
# smoker ann_level_2 Mesothelium cellage done
# smoker ann_level_2 Mesothelium union done
# smoker ann_level_2 Mesothelium common_smoker done
# smoker ann_level_2 Myeloid fridman done
# smoker ann_level_2 Myeloid sasp2 done
# smoker ann_level_2 Myeloid senmayo done
# smoker ann_level_2 Myeloid cellage done
# smoker ann_level_2 Myeloid union done
# smoker ann_level_2 Myeloid common_smoker done
# smoker ann_level_2 Smooth muscle fridman done
# smoker ann_level_2 Smooth muscle sasp2 done
# smoker ann_level_2 Smooth muscle senmayo done
# smoker ann_level_2 Smooth muscle cellage done
# smoker ann_level_2 Smooth muscle union done
# smoker ann_level_2 Smooth muscle common_smoker done
# smoker ann_level_3 AT1 fridman done
# smoker ann_level_3 AT1 sasp2 done
# smoker ann_level_3 AT1 senmayo done
# smoker ann_level_3 AT1 cellage done
# smoker ann_level_3 AT1 union done
# smoker ann_level_3 AT1 common_smoker done
# smoker ann_level_3 AT2 fridman done
# smoker ann_level_3 AT2 sasp2 done
# smoker ann_level_3 AT2 senmayo done
# smoker ann_level_3 AT2 cellage done
# smoker ann_level_3 AT2 union done
# smoker ann_level_3 AT2 common_smoker done
# smoker ann_level_3 B cell lineage fridman done
# smoker ann_level_3 B cell lineage sasp2 done
# smoker ann_level_3 B cell lineage senmayo done
# smoker ann_level_3 B cell lineage cellage done
# smoker ann_level_3 B cell lineage union done
# smoker ann_level_3 B cell lineage common_smoker done
# smoker ann_level_3 Basal fridman done
# smoker ann_level_3 Basal sasp2 done
# smoker ann_level_3 Basal senmayo done
# smoker ann_level_3 Basal cellage done
# smoker ann_level_3 Basal union done
# smoker ann_level_3 Basal common_smoker done
# smoker ann_level_3 Dendritic cells fridman done
# smoker ann_level_3 Dendritic cells sasp2 done
# smoker ann_level_3 Dendritic cells senmayo done
# smoker ann_level_3 Dendritic cells cellage done
# smoker ann_level_3 Dendritic cells union done
# smoker ann_level_3 Dendritic cells common_smoker done
# smoker ann_level_3 EC arterial fridman done
# smoker ann_level_3 EC arterial sasp2 done
# smoker ann_level_3 EC arterial senmayo done
# smoker ann_level_3 EC arterial cellage done
# smoker ann_level_3 EC arterial union done
# smoker ann_level_3 EC arterial common_smoker done
# smoker ann_level_3 EC capillary fridman done
# smoker ann_level_3 EC capillary sasp2 done
# smoker ann_level_3 EC capillary senmayo done
# smoker ann_level_3 EC capillary cellage done
# smoker ann_level_3 EC capillary union done
# smoker ann_level_3 EC capillary common_smoker done
# smoker ann_level_3 EC venous fridman done
# smoker ann_level_3 EC venous sasp2 done
# smoker ann_level_3 EC venous senmayo done
# smoker ann_level_3 EC venous cellage done
# smoker ann_level_3 EC venous union done
# smoker ann_level_3 EC venous common_smoker done
# smoker ann_level_3 Fibroblasts fridman done
# smoker ann_level_3 Fibroblasts sasp2 done
# smoker ann_level_3 Fibroblasts senmayo done
# smoker ann_level_3 Fibroblasts cellage done
# smoker ann_level_3 Fibroblasts union done
# smoker ann_level_3 Fibroblasts common_smoker done
# smoker ann_level_3 Innate lymphoid cell NK fridman done
# smoker ann_level_3 Innate lymphoid cell NK sasp2 done
# smoker ann_level_3 Innate lymphoid cell NK senmayo done
# smoker ann_level_3 Innate lymphoid cell NK cellage done
# smoker ann_level_3 Innate lymphoid cell NK union done
# smoker ann_level_3 Innate lymphoid cell NK common_smoker done
# smoker ann_level_3 Lymphatic EC differentiating fridman done
# smoker ann_level_3 Lymphatic EC differentiating sasp2 done
# smoker ann_level_3 Lymphatic EC differentiating senmayo done
# smoker ann_level_3 Lymphatic EC differentiating cellage done
# smoker ann_level_3 Lymphatic EC differentiating union done
# smoker ann_level_3 Lymphatic EC differentiating common_smoker done
# smoker ann_level_3 Lymphatic EC mature fridman done
# smoker ann_level_3 Lymphatic EC mature sasp2 done
# smoker ann_level_3 Lymphatic EC mature senmayo done
# smoker ann_level_3 Lymphatic EC mature cellage done
# smoker ann_level_3 Lymphatic EC mature union done
# smoker ann_level_3 Lymphatic EC mature common_smoker done
# smoker ann_level_3 Lymphatic EC proliferating fridman done
# smoker ann_level_3 Lymphatic EC proliferating sasp2 done
# smoker ann_level_3 Lymphatic EC proliferating senmayo done
# smoker ann_level_3 Lymphatic EC proliferating cellage done
# smoker ann_level_3 Lymphatic EC proliferating union done
# smoker ann_level_3 Lymphatic EC proliferating common_smoker done
# smoker ann_level_3 Macrophages fridman done
# smoker ann_level_3 Macrophages sasp2 done
# smoker ann_level_3 Macrophages senmayo done
# smoker ann_level_3 Macrophages cellage done
# smoker ann_level_3 Macrophages union done
# smoker ann_level_3 Macrophages common_smoker done
# smoker ann_level_3 Mast cells fridman done
# smoker ann_level_3 Mast cells sasp2 done
# smoker ann_level_3 Mast cells senmayo done
# smoker ann_level_3 Mast cells cellage done
# smoker ann_level_3 Mast cells union done
# smoker ann_level_3 Mast cells common_smoker done
# smoker ann_level_3 Monocytes fridman done
# smoker ann_level_3 Monocytes sasp2 done
# smoker ann_level_3 Monocytes senmayo done
# smoker ann_level_3 Monocytes cellage done
# smoker ann_level_3 Monocytes union done
# smoker ann_level_3 Monocytes common_smoker done
# smoker ann_level_3 Multiciliated lineage fridman done
# smoker ann_level_3 Multiciliated lineage sasp2 done
# smoker ann_level_3 Multiciliated lineage senmayo done
# smoker ann_level_3 Multiciliated lineage cellage done
# smoker ann_level_3 Multiciliated lineage union done
# smoker ann_level_3 Multiciliated lineage common_smoker done
# smoker ann_level_3 Myofibroblasts fridman done
# smoker ann_level_3 Myofibroblasts sasp2 done
# smoker ann_level_3 Myofibroblasts senmayo done
# smoker ann_level_3 Myofibroblasts cellage done
# smoker ann_level_3 Myofibroblasts union done
# smoker ann_level_3 Myofibroblasts common_smoker done
# smoker ann_level_3 Rare fridman done
# smoker ann_level_3 Rare sasp2 done
# smoker ann_level_3 Rare senmayo done
# smoker ann_level_3 Rare cellage done
# smoker ann_level_3 Rare union done
# smoker ann_level_3 Rare common_smoker done
# smoker ann_level_3 SM activated stress response fridman done
# smoker ann_level_3 SM activated stress response sasp2 done
# smoker ann_level_3 SM activated stress response senmayo done
# smoker ann_level_3 SM activated stress response cellage done
# smoker ann_level_3 SM activated stress response union done
# smoker ann_level_3 SM activated stress response common_smoker done
# smoker ann_level_3 Secretory fridman done
# smoker ann_level_3 Secretory sasp2 done
# smoker ann_level_3 Secretory senmayo done
# smoker ann_level_3 Secretory cellage done
# smoker ann_level_3 Secretory union done
# smoker ann_level_3 Secretory common_smoker done
# smoker ann_level_3 Smooth muscle FAM83D+ fridman done
# smoker ann_level_3 Smooth muscle FAM83D+ sasp2 done
# smoker ann_level_3 Smooth muscle FAM83D+ senmayo done
# smoker ann_level_3 Smooth muscle FAM83D+ cellage done
# smoker ann_level_3 Smooth muscle FAM83D+ union done
# smoker ann_level_3 Smooth muscle FAM83D+ common_smoker done
# smoker ann_level_3 T cell lineage fridman done
# smoker ann_level_3 T cell lineage sasp2 done
# smoker ann_level_3 T cell lineage senmayo done
# smoker ann_level_3 T cell lineage cellage done
# smoker ann_level_3 T cell lineage union done
# smoker ann_level_3 T cell lineage common_smoker done
# smoker ann_level_4 AT2 proliferating fridman done
# smoker ann_level_4 AT2 proliferating sasp2 done
# smoker ann_level_4 AT2 proliferating senmayo done
# smoker ann_level_4 AT2 proliferating cellage done
# smoker ann_level_4 AT2 proliferating union done
# smoker ann_level_4 AT2 proliferating common_smoker done
# smoker ann_level_4 Adventitial fibroblasts fridman done
# smoker ann_level_4 Adventitial fibroblasts sasp2 done
# smoker ann_level_4 Adventitial fibroblasts senmayo done
# smoker ann_level_4 Adventitial fibroblasts cellage done
# smoker ann_level_4 Adventitial fibroblasts union done
# smoker ann_level_4 Adventitial fibroblasts common_smoker done
# smoker ann_level_4 Alveolar fibroblasts fridman done
# smoker ann_level_4 Alveolar fibroblasts sasp2 done
# smoker ann_level_4 Alveolar fibroblasts senmayo done
# smoker ann_level_4 Alveolar fibroblasts cellage done
# smoker ann_level_4 Alveolar fibroblasts union done
# smoker ann_level_4 Alveolar fibroblasts common_smoker done
# smoker ann_level_4 Alveolar macrophages fridman done
# smoker ann_level_4 Alveolar macrophages sasp2 done
# smoker ann_level_4 Alveolar macrophages senmayo done
# smoker ann_level_4 Alveolar macrophages cellage done
# smoker ann_level_4 Alveolar macrophages union done
# smoker ann_level_4 Alveolar macrophages common_smoker done
# smoker ann_level_4 B cells fridman done
# smoker ann_level_4 B cells sasp2 done
# smoker ann_level_4 B cells senmayo done
# smoker ann_level_4 B cells cellage done
# smoker ann_level_4 B cells union done
# smoker ann_level_4 B cells common_smoker done
# smoker ann_level_4 Basal resting fridman done
# smoker ann_level_4 Basal resting sasp2 done
# smoker ann_level_4 Basal resting senmayo done
# smoker ann_level_4 Basal resting cellage done
# smoker ann_level_4 Basal resting union done
# smoker ann_level_4 Basal resting common_smoker done
# smoker ann_level_4 CD4 T cells fridman done
# smoker ann_level_4 CD4 T cells sasp2 done
# smoker ann_level_4 CD4 T cells senmayo done
# smoker ann_level_4 CD4 T cells cellage done
# smoker ann_level_4 CD4 T cells union done
# smoker ann_level_4 CD4 T cells common_smoker done
# smoker ann_level_4 CD8 T cells fridman done
# smoker ann_level_4 CD8 T cells sasp2 done
# smoker ann_level_4 CD8 T cells senmayo done
# smoker ann_level_4 CD8 T cells cellage done
# smoker ann_level_4 CD8 T cells union done
# smoker ann_level_4 CD8 T cells common_smoker done
# smoker ann_level_4 Classical monocytes fridman done
# smoker ann_level_4 Classical monocytes sasp2 done
# smoker ann_level_4 Classical monocytes senmayo done
# smoker ann_level_4 Classical monocytes cellage done
# smoker ann_level_4 Classical monocytes union done
# smoker ann_level_4 Classical monocytes common_smoker done
# smoker ann_level_4 Club fridman done
# smoker ann_level_4 Club sasp2 done
# smoker ann_level_4 Club senmayo done
# smoker ann_level_4 Club cellage done
# smoker ann_level_4 Club union done
# smoker ann_level_4 Club common_smoker done
# smoker ann_level_4 DC1 fridman done
# smoker ann_level_4 DC1 sasp2 done
# smoker ann_level_4 DC1 senmayo done
# smoker ann_level_4 DC1 cellage done
# smoker ann_level_4 DC1 union done
# smoker ann_level_4 DC1 common_smoker done
# smoker ann_level_4 DC2 fridman done
# smoker ann_level_4 DC2 sasp2 done
# smoker ann_level_4 DC2 senmayo done
# smoker ann_level_4 DC2 cellage done
# smoker ann_level_4 DC2 union done
# smoker ann_level_4 DC2 common_smoker done
# smoker ann_level_4 Deuterosomal fridman done
# smoker ann_level_4 Deuterosomal sasp2 done
# smoker ann_level_4 Deuterosomal senmayo done
# smoker ann_level_4 Deuterosomal cellage done
# smoker ann_level_4 Deuterosomal union done
# smoker ann_level_4 Deuterosomal common_smoker done
# smoker ann_level_4 EC aerocyte capillary fridman done
# smoker ann_level_4 EC aerocyte capillary sasp2 done
# smoker ann_level_4 EC aerocyte capillary senmayo done
# smoker ann_level_4 EC aerocyte capillary cellage done
# smoker ann_level_4 EC aerocyte capillary union done
# smoker ann_level_4 EC aerocyte capillary common_smoker done
# smoker ann_level_4 EC general capillary fridman done
# smoker ann_level_4 EC general capillary sasp2 done
# smoker ann_level_4 EC general capillary senmayo done
# smoker ann_level_4 EC general capillary cellage done
# smoker ann_level_4 EC general capillary union done
# smoker ann_level_4 EC general capillary common_smoker done
# smoker ann_level_4 EC venous pulmonary fridman done
# smoker ann_level_4 EC venous pulmonary sasp2 done
# smoker ann_level_4 EC venous pulmonary senmayo done
# smoker ann_level_4 EC venous pulmonary cellage done
# smoker ann_level_4 EC venous pulmonary union done
# smoker ann_level_4 EC venous pulmonary common_smoker done
# smoker ann_level_4 EC venous systemic fridman done
# smoker ann_level_4 EC venous systemic sasp2 done
# smoker ann_level_4 EC venous systemic senmayo done
# smoker ann_level_4 EC venous systemic cellage done
# smoker ann_level_4 EC venous systemic union done
# smoker ann_level_4 EC venous systemic common_smoker done
# smoker ann_level_4 Goblet fridman done
# smoker ann_level_4 Goblet sasp2 done
# smoker ann_level_4 Goblet senmayo done
# smoker ann_level_4 Goblet cellage done
# smoker ann_level_4 Goblet union done
# smoker ann_level_4 Goblet common_smoker done
# smoker ann_level_4 Hillock-like fridman done
# smoker ann_level_4 Hillock-like sasp2 done
# smoker ann_level_4 Hillock-like senmayo done
# smoker ann_level_4 Hillock-like cellage done
# smoker ann_level_4 Hillock-like union done
# smoker ann_level_4 Hillock-like common_smoker done
# smoker ann_level_4 Interstitial macrophages fridman done
# smoker ann_level_4 Interstitial macrophages sasp2 done
# smoker ann_level_4 Interstitial macrophages senmayo done
# smoker ann_level_4 Interstitial macrophages cellage done
# smoker ann_level_4 Interstitial macrophages union done
# smoker ann_level_4 Interstitial macrophages common_smoker done
# smoker ann_level_4 Ionocyte fridman done
# smoker ann_level_4 Ionocyte sasp2 done
# smoker ann_level_4 Ionocyte senmayo done
# smoker ann_level_4 Ionocyte cellage done
# smoker ann_level_4 Ionocyte union done
# smoker ann_level_4 Ionocyte common_smoker done
# smoker ann_level_4 Migratory DCs fridman done
# smoker ann_level_4 Migratory DCs sasp2 done
# smoker ann_level_4 Migratory DCs senmayo done
# smoker ann_level_4 Migratory DCs cellage done
# smoker ann_level_4 Migratory DCs union done
# smoker ann_level_4 Migratory DCs common_smoker done
# smoker ann_level_4 Multiciliated fridman done
# smoker ann_level_4 Multiciliated sasp2 done
# smoker ann_level_4 Multiciliated senmayo done
# smoker ann_level_4 Multiciliated cellage done
# smoker ann_level_4 Multiciliated union done
# smoker ann_level_4 Multiciliated common_smoker done
# smoker ann_level_4 NK cells fridman done
# smoker ann_level_4 NK cells sasp2 done
# smoker ann_level_4 NK cells senmayo done
# smoker ann_level_4 NK cells cellage done
# smoker ann_level_4 NK cells union done
# smoker ann_level_4 NK cells common_smoker done
# smoker ann_level_4 Neuroendocrine fridman done
# smoker ann_level_4 Neuroendocrine sasp2 done
# smoker ann_level_4 Neuroendocrine senmayo done
# smoker ann_level_4 Neuroendocrine cellage done
# smoker ann_level_4 Neuroendocrine union done
# smoker ann_level_4 Neuroendocrine common_smoker done
# smoker ann_level_4 Non-classical monocytes fridman done
# smoker ann_level_4 Non-classical monocytes sasp2 done
# smoker ann_level_4 Non-classical monocytes senmayo done
# smoker ann_level_4 Non-classical monocytes cellage done
# smoker ann_level_4 Non-classical monocytes union done
# smoker ann_level_4 Non-classical monocytes common_smoker done
# smoker ann_level_4 Peribronchial fibroblasts fridman done
# smoker ann_level_4 Peribronchial fibroblasts sasp2 done
# smoker ann_level_4 Peribronchial fibroblasts senmayo done
# smoker ann_level_4 Peribronchial fibroblasts cellage done
# smoker ann_level_4 Peribronchial fibroblasts union done
# smoker ann_level_4 Peribronchial fibroblasts common_smoker done
# smoker ann_level_4 Pericytes fridman done
# smoker ann_level_4 Pericytes sasp2 done
# smoker ann_level_4 Pericytes senmayo done
# smoker ann_level_4 Pericytes cellage done
# smoker ann_level_4 Pericytes union done
# smoker ann_level_4 Pericytes common_smoker done
# smoker ann_level_4 Plasma cells fridman done
# smoker ann_level_4 Plasma cells sasp2 done
# smoker ann_level_4 Plasma cells senmayo done
# smoker ann_level_4 Plasma cells cellage done
# smoker ann_level_4 Plasma cells union done
# smoker ann_level_4 Plasma cells common_smoker done
# smoker ann_level_4 Plasmacytoid DCs fridman done
# smoker ann_level_4 Plasmacytoid DCs sasp2 done
# smoker ann_level_4 Plasmacytoid DCs senmayo done
# smoker ann_level_4 Plasmacytoid DCs cellage done
# smoker ann_level_4 Plasmacytoid DCs union done
# smoker ann_level_4 Plasmacytoid DCs common_smoker done
# smoker ann_level_4 Subpleural fibroblasts fridman done
# smoker ann_level_4 Subpleural fibroblasts sasp2 done
# smoker ann_level_4 Subpleural fibroblasts senmayo done
# smoker ann_level_4 Subpleural fibroblasts cellage done
# smoker ann_level_4 Subpleural fibroblasts union done
# smoker ann_level_4 Subpleural fibroblasts common_smoker done
# smoker ann_level_4 Suprabasal fridman done
# smoker ann_level_4 Suprabasal sasp2 done
# smoker ann_level_4 Suprabasal senmayo done
# smoker ann_level_4 Suprabasal cellage done
# smoker ann_level_4 Suprabasal union done
# smoker ann_level_4 Suprabasal common_smoker done
# smoker ann_level_4 T cells proliferating fridman done
# smoker ann_level_4 T cells proliferating sasp2 done
# smoker ann_level_4 T cells proliferating senmayo done
# smoker ann_level_4 T cells proliferating cellage done
# smoker ann_level_4 T cells proliferating union done
# smoker ann_level_4 T cells proliferating common_smoker done
# smoker ann_level_4 Transitional Club-AT2 fridman done
# smoker ann_level_4 Transitional Club-AT2 sasp2 done
# smoker ann_level_4 Transitional Club-AT2 senmayo done
# smoker ann_level_4 Transitional Club-AT2 cellage done
# smoker ann_level_4 Transitional Club-AT2 union done
# smoker ann_level_4 Transitional Club-AT2 common_smoker done
# smoker ann_level_4 Tuft fridman done
# smoker ann_level_4 Tuft sasp2 done
# smoker ann_level_4 Tuft senmayo done
# smoker ann_level_4 Tuft cellage done
# smoker ann_level_4 Tuft union done
# smoker ann_level_4 Tuft common_smoker done
# smoker ann_level_5 AT0 fridman done
# smoker ann_level_5 AT0 sasp2 done
# smoker ann_level_5 AT0 senmayo done
# smoker ann_level_5 AT0 cellage done
# smoker ann_level_5 AT0 union done
# smoker ann_level_5 AT0 common_smoker done
# smoker ann_level_5 Alveolar Mph CCL3+ fridman done
# smoker ann_level_5 Alveolar Mph CCL3+ sasp2 done
# smoker ann_level_5 Alveolar Mph CCL3+ senmayo done
# smoker ann_level_5 Alveolar Mph CCL3+ cellage done
# smoker ann_level_5 Alveolar Mph CCL3+ union done
# smoker ann_level_5 Alveolar Mph CCL3+ common_smoker done
# smoker ann_level_5 Alveolar Mph MT-positive fridman done
# smoker ann_level_5 Alveolar Mph MT-positive sasp2 done
# smoker ann_level_5 Alveolar Mph MT-positive senmayo done
# smoker ann_level_5 Alveolar Mph MT-positive cellage done
# smoker ann_level_5 Alveolar Mph MT-positive union done
# smoker ann_level_5 Alveolar Mph MT-positive common_smoker done
# smoker ann_level_5 Alveolar Mph proliferating fridman done
# smoker ann_level_5 Alveolar Mph proliferating sasp2 done
# smoker ann_level_5 Alveolar Mph proliferating senmayo done
# smoker ann_level_5 Alveolar Mph proliferating cellage done
# smoker ann_level_5 Alveolar Mph proliferating union done
# smoker ann_level_5 Alveolar Mph proliferating common_smoker done
# smoker ann_level_5 Club (non-nasal) fridman done
# smoker ann_level_5 Club (non-nasal) sasp2 done
# smoker ann_level_5 Club (non-nasal) senmayo done
# smoker ann_level_5 Club (non-nasal) cellage done
# smoker ann_level_5 Club (non-nasal) union done
# smoker ann_level_5 Club (non-nasal) common_smoker done
# smoker ann_level_5 Goblet (bronchial) fridman done
# smoker ann_level_5 Goblet (bronchial) sasp2 done
# smoker ann_level_5 Goblet (bronchial) senmayo done
# smoker ann_level_5 Goblet (bronchial) cellage done
# smoker ann_level_5 Goblet (bronchial) union done
# smoker ann_level_5 Goblet (bronchial) common_smoker done
# smoker ann_level_5 Goblet (subsegmental) fridman done
# smoker ann_level_5 Goblet (subsegmental) sasp2 done
# smoker ann_level_5 Goblet (subsegmental) senmayo done
# smoker ann_level_5 Goblet (subsegmental) cellage done
# smoker ann_level_5 Goblet (subsegmental) union done
# smoker ann_level_5 Goblet (subsegmental) common_smoker done
# smoker ann_level_5 Interstitial Mph perivascular fridman done
# smoker ann_level_5 Interstitial Mph perivascular sasp2 done
# smoker ann_level_5 Interstitial Mph perivascular senmayo done
# smoker ann_level_5 Interstitial Mph perivascular cellage done
# smoker ann_level_5 Interstitial Mph perivascular union done
# smoker ann_level_5 Interstitial Mph perivascular common_smoker done
# smoker ann_level_5 Monocyte-derived Mph fridman done
# smoker ann_level_5 Monocyte-derived Mph sasp2 done
# smoker ann_level_5 Monocyte-derived Mph senmayo done
# smoker ann_level_5 Monocyte-derived Mph cellage done
# smoker ann_level_5 Monocyte-derived Mph union done
# smoker ann_level_5 Monocyte-derived Mph common_smoker done
# smoker ann_level_5 Multiciliated (non-nasal) fridman done
# smoker ann_level_5 Multiciliated (non-nasal) sasp2 done
# smoker ann_level_5 Multiciliated (non-nasal) senmayo done
# smoker ann_level_5 Multiciliated (non-nasal) cellage done
# smoker ann_level_5 Multiciliated (non-nasal) union done
# smoker ann_level_5 Multiciliated (non-nasal) common_smoker done
# smoker ann_level_5 pre-TB secretory fridman done
# smoker ann_level_5 pre-TB secretory sasp2 done
# smoker ann_level_5 pre-TB secretory senmayo done
# smoker ann_level_5 pre-TB secretory cellage done
# smoker ann_level_5 pre-TB secretory union done
# smoker ann_level_5 pre-TB secretory common_smoker done
# nonsmoker ann_level_2 Airway epithelium fridman done
# nonsmoker ann_level_2 Airway epithelium sasp2 done
# nonsmoker ann_level_2 Airway epithelium senmayo done
# nonsmoker ann_level_2 Airway epithelium cellage done
# nonsmoker ann_level_2 Airway epithelium union done
# nonsmoker ann_level_2 Airway epithelium common_nonsmoker done
# nonsmoker ann_level_2 Alveolar epithelium fridman done
# nonsmoker ann_level_2 Alveolar epithelium sasp2 done
# nonsmoker ann_level_2 Alveolar epithelium senmayo done
# nonsmoker ann_level_2 Alveolar epithelium cellage done
# nonsmoker ann_level_2 Alveolar epithelium union done
# nonsmoker ann_level_2 Alveolar epithelium common_nonsmoker done
# nonsmoker ann_level_2 Blood vessels fridman done
# nonsmoker ann_level_2 Blood vessels sasp2 done
# nonsmoker ann_level_2 Blood vessels senmayo done
# nonsmoker ann_level_2 Blood vessels cellage done
# nonsmoker ann_level_2 Blood vessels union done
# nonsmoker ann_level_2 Blood vessels common_nonsmoker done
# nonsmoker ann_level_2 Fibroblast lineage fridman done
# nonsmoker ann_level_2 Fibroblast lineage sasp2 done
# nonsmoker ann_level_2 Fibroblast lineage senmayo done
# nonsmoker ann_level_2 Fibroblast lineage cellage done
# nonsmoker ann_level_2 Fibroblast lineage union done
# nonsmoker ann_level_2 Fibroblast lineage common_nonsmoker done
# nonsmoker ann_level_2 Hematopoietic stem cells fridman done
# nonsmoker ann_level_2 Hematopoietic stem cells sasp2 done
# nonsmoker ann_level_2 Hematopoietic stem cells senmayo done
# nonsmoker ann_level_2 Hematopoietic stem cells cellage done
# nonsmoker ann_level_2 Hematopoietic stem cells union done
# nonsmoker ann_level_2 Hematopoietic stem cells common_nonsmoker done
# nonsmoker ann_level_2 Lymphatic EC fridman done
# nonsmoker ann_level_2 Lymphatic EC sasp2 done
# nonsmoker ann_level_2 Lymphatic EC senmayo done
# nonsmoker ann_level_2 Lymphatic EC cellage done
# nonsmoker ann_level_2 Lymphatic EC union done
# nonsmoker ann_level_2 Lymphatic EC common_nonsmoker done
# nonsmoker ann_level_2 Lymphoid fridman done
# nonsmoker ann_level_2 Lymphoid sasp2 done
# nonsmoker ann_level_2 Lymphoid senmayo done
# nonsmoker ann_level_2 Lymphoid cellage done
# nonsmoker ann_level_2 Lymphoid union done
# nonsmoker ann_level_2 Lymphoid common_nonsmoker done
# nonsmoker ann_level_2 Mesothelium fridman done
# nonsmoker ann_level_2 Mesothelium sasp2 done
# nonsmoker ann_level_2 Mesothelium senmayo done
# nonsmoker ann_level_2 Mesothelium cellage done
# nonsmoker ann_level_2 Mesothelium union done
# nonsmoker ann_level_2 Mesothelium common_nonsmoker done
# nonsmoker ann_level_2 Myeloid fridman done
# nonsmoker ann_level_2 Myeloid sasp2 done
# nonsmoker ann_level_2 Myeloid senmayo done
# nonsmoker ann_level_2 Myeloid cellage done
# nonsmoker ann_level_2 Myeloid union done
# nonsmoker ann_level_2 Myeloid common_nonsmoker done
# nonsmoker ann_level_2 Smooth muscle fridman done
# nonsmoker ann_level_2 Smooth muscle sasp2 done
# nonsmoker ann_level_2 Smooth muscle senmayo done
# nonsmoker ann_level_2 Smooth muscle cellage done
# nonsmoker ann_level_2 Smooth muscle union done
# nonsmoker ann_level_2 Smooth muscle common_nonsmoker done
# nonsmoker ann_level_2 Submucosal Gland fridman done
# nonsmoker ann_level_2 Submucosal Gland sasp2 done
# nonsmoker ann_level_2 Submucosal Gland senmayo done
# nonsmoker ann_level_2 Submucosal Gland cellage done
# nonsmoker ann_level_2 Submucosal Gland union done
# nonsmoker ann_level_2 Submucosal Gland common_nonsmoker done
# nonsmoker ann_level_3 AT1 fridman done
# nonsmoker ann_level_3 AT1 sasp2 done
# nonsmoker ann_level_3 AT1 senmayo done
# nonsmoker ann_level_3 AT1 cellage done
# nonsmoker ann_level_3 AT1 union done
# nonsmoker ann_level_3 AT1 common_nonsmoker done
# nonsmoker ann_level_3 AT2 fridman done
# nonsmoker ann_level_3 AT2 sasp2 done
# nonsmoker ann_level_3 AT2 senmayo done
# nonsmoker ann_level_3 AT2 cellage done
# nonsmoker ann_level_3 AT2 union done
# nonsmoker ann_level_3 AT2 common_nonsmoker done
# nonsmoker ann_level_3 B cell lineage fridman done
# nonsmoker ann_level_3 B cell lineage sasp2 done
# nonsmoker ann_level_3 B cell lineage senmayo done
# nonsmoker ann_level_3 B cell lineage cellage done
# nonsmoker ann_level_3 B cell lineage union done
# nonsmoker ann_level_3 B cell lineage common_nonsmoker done
# nonsmoker ann_level_3 Basal fridman done
# nonsmoker ann_level_3 Basal sasp2 done
# nonsmoker ann_level_3 Basal senmayo done
# nonsmoker ann_level_3 Basal cellage done
# nonsmoker ann_level_3 Basal union done
# nonsmoker ann_level_3 Basal common_nonsmoker done
# nonsmoker ann_level_3 Dendritic cells fridman done
# nonsmoker ann_level_3 Dendritic cells sasp2 done
# nonsmoker ann_level_3 Dendritic cells senmayo done
# nonsmoker ann_level_3 Dendritic cells cellage done
# nonsmoker ann_level_3 Dendritic cells union done
# nonsmoker ann_level_3 Dendritic cells common_nonsmoker done
# nonsmoker ann_level_3 EC arterial fridman done
# nonsmoker ann_level_3 EC arterial sasp2 done
# nonsmoker ann_level_3 EC arterial senmayo done
# nonsmoker ann_level_3 EC arterial cellage done
# nonsmoker ann_level_3 EC arterial union done
# nonsmoker ann_level_3 EC arterial common_nonsmoker done
# nonsmoker ann_level_3 EC capillary fridman done
# nonsmoker ann_level_3 EC capillary sasp2 done
# nonsmoker ann_level_3 EC capillary senmayo done
# nonsmoker ann_level_3 EC capillary cellage done
# nonsmoker ann_level_3 EC capillary union done
# nonsmoker ann_level_3 EC capillary common_nonsmoker done
# nonsmoker ann_level_3 EC venous fridman done
# nonsmoker ann_level_3 EC venous sasp2 done
# nonsmoker ann_level_3 EC venous senmayo done
# nonsmoker ann_level_3 EC venous cellage done
# nonsmoker ann_level_3 EC venous union done
# nonsmoker ann_level_3 EC venous common_nonsmoker done
# nonsmoker ann_level_3 Fibroblasts fridman done
# nonsmoker ann_level_3 Fibroblasts sasp2 done
# nonsmoker ann_level_3 Fibroblasts senmayo done
# nonsmoker ann_level_3 Fibroblasts cellage done
# nonsmoker ann_level_3 Fibroblasts union done
# nonsmoker ann_level_3 Fibroblasts common_nonsmoker done
# nonsmoker ann_level_3 Innate lymphoid cell NK fridman done
# nonsmoker ann_level_3 Innate lymphoid cell NK sasp2 done
# nonsmoker ann_level_3 Innate lymphoid cell NK senmayo done
# nonsmoker ann_level_3 Innate lymphoid cell NK cellage done
# nonsmoker ann_level_3 Innate lymphoid cell NK union done
# nonsmoker ann_level_3 Innate lymphoid cell NK common_nonsmoker done
# nonsmoker ann_level_3 Lymphatic EC differentiating fridman done
# nonsmoker ann_level_3 Lymphatic EC differentiating sasp2 done
# nonsmoker ann_level_3 Lymphatic EC differentiating senmayo done
# nonsmoker ann_level_3 Lymphatic EC differentiating cellage done
# nonsmoker ann_level_3 Lymphatic EC differentiating union done
# nonsmoker ann_level_3 Lymphatic EC differentiating common_nonsmoker done
# nonsmoker ann_level_3 Lymphatic EC mature fridman done
# nonsmoker ann_level_3 Lymphatic EC mature sasp2 done
# nonsmoker ann_level_3 Lymphatic EC mature senmayo done
# nonsmoker ann_level_3 Lymphatic EC mature cellage done
# nonsmoker ann_level_3 Lymphatic EC mature union done
# nonsmoker ann_level_3 Lymphatic EC mature common_nonsmoker done
# nonsmoker ann_level_3 Lymphatic EC proliferating fridman done
# nonsmoker ann_level_3 Lymphatic EC proliferating sasp2 done
# nonsmoker ann_level_3 Lymphatic EC proliferating senmayo done
# nonsmoker ann_level_3 Lymphatic EC proliferating cellage done
# nonsmoker ann_level_3 Lymphatic EC proliferating union done
# nonsmoker ann_level_3 Lymphatic EC proliferating common_nonsmoker done
# nonsmoker ann_level_3 Macrophages fridman done
# nonsmoker ann_level_3 Macrophages sasp2 done
# nonsmoker ann_level_3 Macrophages senmayo done
# nonsmoker ann_level_3 Macrophages cellage done
# nonsmoker ann_level_3 Macrophages union done
# nonsmoker ann_level_3 Macrophages common_nonsmoker done
# nonsmoker ann_level_3 Mast cells fridman done
# nonsmoker ann_level_3 Mast cells sasp2 done
# nonsmoker ann_level_3 Mast cells senmayo done
# nonsmoker ann_level_3 Mast cells cellage done
# nonsmoker ann_level_3 Mast cells union done
# nonsmoker ann_level_3 Mast cells common_nonsmoker done
# nonsmoker ann_level_3 Monocytes fridman done
# nonsmoker ann_level_3 Monocytes sasp2 done
# nonsmoker ann_level_3 Monocytes senmayo done
# nonsmoker ann_level_3 Monocytes cellage done
# nonsmoker ann_level_3 Monocytes union done
# nonsmoker ann_level_3 Monocytes common_nonsmoker done
# nonsmoker ann_level_3 Multiciliated lineage fridman done
# nonsmoker ann_level_3 Multiciliated lineage sasp2 done
# nonsmoker ann_level_3 Multiciliated lineage senmayo done
# nonsmoker ann_level_3 Multiciliated lineage cellage done
# nonsmoker ann_level_3 Multiciliated lineage union done
# nonsmoker ann_level_3 Multiciliated lineage common_nonsmoker done
# nonsmoker ann_level_3 Myofibroblasts fridman done
# nonsmoker ann_level_3 Myofibroblasts sasp2 done
# nonsmoker ann_level_3 Myofibroblasts senmayo done
# nonsmoker ann_level_3 Myofibroblasts cellage done
# nonsmoker ann_level_3 Myofibroblasts union done
# nonsmoker ann_level_3 Myofibroblasts common_nonsmoker done
# nonsmoker ann_level_3 Rare fridman done
# nonsmoker ann_level_3 Rare sasp2 done
# nonsmoker ann_level_3 Rare senmayo done
# nonsmoker ann_level_3 Rare cellage done
# nonsmoker ann_level_3 Rare union done
# nonsmoker ann_level_3 Rare common_nonsmoker done
# nonsmoker ann_level_3 SM activated stress response fridman done
# nonsmoker ann_level_3 SM activated stress response sasp2 done
# nonsmoker ann_level_3 SM activated stress response senmayo done
# nonsmoker ann_level_3 SM activated stress response cellage done
# nonsmoker ann_level_3 SM activated stress response union done
# nonsmoker ann_level_3 SM activated stress response common_nonsmoker done
# nonsmoker ann_level_3 Secretory fridman done
# nonsmoker ann_level_3 Secretory sasp2 done
# nonsmoker ann_level_3 Secretory senmayo done
# nonsmoker ann_level_3 Secretory cellage done
# nonsmoker ann_level_3 Secretory union done
# nonsmoker ann_level_3 Secretory common_nonsmoker done
# nonsmoker ann_level_3 Smooth muscle FAM83D+ fridman done
# nonsmoker ann_level_3 Smooth muscle FAM83D+ sasp2 done
# nonsmoker ann_level_3 Smooth muscle FAM83D+ senmayo done
# nonsmoker ann_level_3 Smooth muscle FAM83D+ cellage done
# nonsmoker ann_level_3 Smooth muscle FAM83D+ union done
# nonsmoker ann_level_3 Smooth muscle FAM83D+ common_nonsmoker done
# nonsmoker ann_level_3 Submucosal Secretory fridman done
# nonsmoker ann_level_3 Submucosal Secretory sasp2 done
# nonsmoker ann_level_3 Submucosal Secretory senmayo done
# nonsmoker ann_level_3 Submucosal Secretory cellage done
# nonsmoker ann_level_3 Submucosal Secretory union done
# nonsmoker ann_level_3 Submucosal Secretory common_nonsmoker done
# nonsmoker ann_level_3 T cell lineage fridman done
# nonsmoker ann_level_3 T cell lineage sasp2 done
# nonsmoker ann_level_3 T cell lineage senmayo done
# nonsmoker ann_level_3 T cell lineage cellage done
# nonsmoker ann_level_3 T cell lineage union done
# nonsmoker ann_level_3 T cell lineage common_nonsmoker done
# nonsmoker ann_level_4 AT2 proliferating fridman done
# nonsmoker ann_level_4 AT2 proliferating sasp2 done
# nonsmoker ann_level_4 AT2 proliferating senmayo done
# nonsmoker ann_level_4 AT2 proliferating cellage done
# nonsmoker ann_level_4 AT2 proliferating union done
# nonsmoker ann_level_4 AT2 proliferating common_nonsmoker done
# nonsmoker ann_level_4 Adventitial fibroblasts fridman done
# nonsmoker ann_level_4 Adventitial fibroblasts sasp2 done
# nonsmoker ann_level_4 Adventitial fibroblasts senmayo done
# nonsmoker ann_level_4 Adventitial fibroblasts cellage done
# nonsmoker ann_level_4 Adventitial fibroblasts union done
# nonsmoker ann_level_4 Adventitial fibroblasts common_nonsmoker done
# nonsmoker ann_level_4 Alveolar fibroblasts fridman done
# nonsmoker ann_level_4 Alveolar fibroblasts sasp2 done
# nonsmoker ann_level_4 Alveolar fibroblasts senmayo done
# nonsmoker ann_level_4 Alveolar fibroblasts cellage done
# nonsmoker ann_level_4 Alveolar fibroblasts union done
# nonsmoker ann_level_4 Alveolar fibroblasts common_nonsmoker done
# nonsmoker ann_level_4 Alveolar macrophages fridman done
# nonsmoker ann_level_4 Alveolar macrophages sasp2 done
# nonsmoker ann_level_4 Alveolar macrophages senmayo done
# nonsmoker ann_level_4 Alveolar macrophages cellage done
# nonsmoker ann_level_4 Alveolar macrophages union done
# nonsmoker ann_level_4 Alveolar macrophages common_nonsmoker done
# nonsmoker ann_level_4 B cells fridman done
# nonsmoker ann_level_4 B cells sasp2 done
# nonsmoker ann_level_4 B cells senmayo done
# nonsmoker ann_level_4 B cells cellage done
# nonsmoker ann_level_4 B cells union done
# nonsmoker ann_level_4 B cells common_nonsmoker done
# nonsmoker ann_level_4 Basal resting fridman done
# nonsmoker ann_level_4 Basal resting sasp2 done
# nonsmoker ann_level_4 Basal resting senmayo done
# nonsmoker ann_level_4 Basal resting cellage done
# nonsmoker ann_level_4 Basal resting union done
# nonsmoker ann_level_4 Basal resting common_nonsmoker done
# nonsmoker ann_level_4 CD4 T cells fridman done
# nonsmoker ann_level_4 CD4 T cells sasp2 done
# nonsmoker ann_level_4 CD4 T cells senmayo done
# nonsmoker ann_level_4 CD4 T cells cellage done
# nonsmoker ann_level_4 CD4 T cells union done
# nonsmoker ann_level_4 CD4 T cells common_nonsmoker done
# nonsmoker ann_level_4 CD8 T cells fridman done
# nonsmoker ann_level_4 CD8 T cells sasp2 done
# nonsmoker ann_level_4 CD8 T cells senmayo done
# nonsmoker ann_level_4 CD8 T cells cellage done
# nonsmoker ann_level_4 CD8 T cells union done
# nonsmoker ann_level_4 CD8 T cells common_nonsmoker done
# nonsmoker ann_level_4 Classical monocytes fridman done
# nonsmoker ann_level_4 Classical monocytes sasp2 done
# nonsmoker ann_level_4 Classical monocytes senmayo done
# nonsmoker ann_level_4 Classical monocytes cellage done
# nonsmoker ann_level_4 Classical monocytes union done
# nonsmoker ann_level_4 Classical monocytes common_nonsmoker done
# nonsmoker ann_level_4 Club fridman done
# nonsmoker ann_level_4 Club sasp2 done
# nonsmoker ann_level_4 Club senmayo done
# nonsmoker ann_level_4 Club cellage done
# nonsmoker ann_level_4 Club union done
# nonsmoker ann_level_4 Club common_nonsmoker done
# nonsmoker ann_level_4 DC1 fridman done
# nonsmoker ann_level_4 DC1 sasp2 done
# nonsmoker ann_level_4 DC1 senmayo done
# nonsmoker ann_level_4 DC1 cellage done
# nonsmoker ann_level_4 DC1 union done
# nonsmoker ann_level_4 DC1 common_nonsmoker done
# nonsmoker ann_level_4 DC2 fridman done
# nonsmoker ann_level_4 DC2 sasp2 done
# nonsmoker ann_level_4 DC2 senmayo done
# nonsmoker ann_level_4 DC2 cellage done
# nonsmoker ann_level_4 DC2 union done
# nonsmoker ann_level_4 DC2 common_nonsmoker done
# nonsmoker ann_level_4 Deuterosomal fridman done
# nonsmoker ann_level_4 Deuterosomal sasp2 done
# nonsmoker ann_level_4 Deuterosomal senmayo done
# nonsmoker ann_level_4 Deuterosomal cellage done
# nonsmoker ann_level_4 Deuterosomal union done
# nonsmoker ann_level_4 Deuterosomal common_nonsmoker done
# nonsmoker ann_level_4 EC aerocyte capillary fridman done
# nonsmoker ann_level_4 EC aerocyte capillary sasp2 done
# nonsmoker ann_level_4 EC aerocyte capillary senmayo done
# nonsmoker ann_level_4 EC aerocyte capillary cellage done
# nonsmoker ann_level_4 EC aerocyte capillary union done
# nonsmoker ann_level_4 EC aerocyte capillary common_nonsmoker done
# nonsmoker ann_level_4 EC general capillary fridman done
# nonsmoker ann_level_4 EC general capillary sasp2 done
# nonsmoker ann_level_4 EC general capillary senmayo done
# nonsmoker ann_level_4 EC general capillary cellage done
# nonsmoker ann_level_4 EC general capillary union done
# nonsmoker ann_level_4 EC general capillary common_nonsmoker done
# nonsmoker ann_level_4 EC venous pulmonary fridman done
# nonsmoker ann_level_4 EC venous pulmonary sasp2 done
# nonsmoker ann_level_4 EC venous pulmonary senmayo done
# nonsmoker ann_level_4 EC venous pulmonary cellage done
# nonsmoker ann_level_4 EC venous pulmonary union done
# nonsmoker ann_level_4 EC venous pulmonary common_nonsmoker done
# nonsmoker ann_level_4 EC venous systemic fridman done
# nonsmoker ann_level_4 EC venous systemic sasp2 done
# nonsmoker ann_level_4 EC venous systemic senmayo done
# nonsmoker ann_level_4 EC venous systemic cellage done
# nonsmoker ann_level_4 EC venous systemic union done
# nonsmoker ann_level_4 EC venous systemic common_nonsmoker done
# nonsmoker ann_level_4 Goblet fridman done
# nonsmoker ann_level_4 Goblet sasp2 done
# nonsmoker ann_level_4 Goblet senmayo done
# nonsmoker ann_level_4 Goblet cellage done
# nonsmoker ann_level_4 Goblet union done
# nonsmoker ann_level_4 Goblet common_nonsmoker done
# nonsmoker ann_level_4 Interstitial macrophages fridman done
# nonsmoker ann_level_4 Interstitial macrophages sasp2 done
# nonsmoker ann_level_4 Interstitial macrophages senmayo done
# nonsmoker ann_level_4 Interstitial macrophages cellage done
# nonsmoker ann_level_4 Interstitial macrophages union done
# nonsmoker ann_level_4 Interstitial macrophages common_nonsmoker done
# nonsmoker ann_level_4 Ionocyte fridman done
# nonsmoker ann_level_4 Ionocyte sasp2 done
# nonsmoker ann_level_4 Ionocyte senmayo done
# nonsmoker ann_level_4 Ionocyte cellage done
# nonsmoker ann_level_4 Ionocyte union done
# nonsmoker ann_level_4 Ionocyte common_nonsmoker done
# nonsmoker ann_level_4 Migratory DCs fridman done
# nonsmoker ann_level_4 Migratory DCs sasp2 done
# nonsmoker ann_level_4 Migratory DCs senmayo done
# nonsmoker ann_level_4 Migratory DCs cellage done
# nonsmoker ann_level_4 Migratory DCs union done
# nonsmoker ann_level_4 Migratory DCs common_nonsmoker done
# nonsmoker ann_level_4 Multiciliated fridman done
# nonsmoker ann_level_4 Multiciliated sasp2 done
# nonsmoker ann_level_4 Multiciliated senmayo done
# nonsmoker ann_level_4 Multiciliated cellage done
# nonsmoker ann_level_4 Multiciliated union done
# nonsmoker ann_level_4 Multiciliated common_nonsmoker done
# nonsmoker ann_level_4 NK cells fridman done
# nonsmoker ann_level_4 NK cells sasp2 done
# nonsmoker ann_level_4 NK cells senmayo done
# nonsmoker ann_level_4 NK cells cellage done
# nonsmoker ann_level_4 NK cells union done
# nonsmoker ann_level_4 NK cells common_nonsmoker done
# nonsmoker ann_level_4 Neuroendocrine fridman done
# nonsmoker ann_level_4 Neuroendocrine sasp2 done
# nonsmoker ann_level_4 Neuroendocrine senmayo done
# nonsmoker ann_level_4 Neuroendocrine cellage done
# nonsmoker ann_level_4 Neuroendocrine union done
# nonsmoker ann_level_4 Neuroendocrine common_nonsmoker done
# nonsmoker ann_level_4 Non-classical monocytes fridman done
# nonsmoker ann_level_4 Non-classical monocytes sasp2 done
# nonsmoker ann_level_4 Non-classical monocytes senmayo done
# nonsmoker ann_level_4 Non-classical monocytes cellage done
# nonsmoker ann_level_4 Non-classical monocytes union done
# nonsmoker ann_level_4 Non-classical monocytes common_nonsmoker done
# nonsmoker ann_level_4 Peribronchial fibroblasts fridman done
# nonsmoker ann_level_4 Peribronchial fibroblasts sasp2 done
# nonsmoker ann_level_4 Peribronchial fibroblasts senmayo done
# nonsmoker ann_level_4 Peribronchial fibroblasts cellage done
# nonsmoker ann_level_4 Peribronchial fibroblasts union done
# nonsmoker ann_level_4 Peribronchial fibroblasts common_nonsmoker done
# nonsmoker ann_level_4 Pericytes fridman done
# nonsmoker ann_level_4 Pericytes sasp2 done
# nonsmoker ann_level_4 Pericytes senmayo done
# nonsmoker ann_level_4 Pericytes cellage done
# nonsmoker ann_level_4 Pericytes union done
# nonsmoker ann_level_4 Pericytes common_nonsmoker done
# nonsmoker ann_level_4 Plasma cells fridman done
# nonsmoker ann_level_4 Plasma cells sasp2 done
# nonsmoker ann_level_4 Plasma cells senmayo done
# nonsmoker ann_level_4 Plasma cells cellage done
# nonsmoker ann_level_4 Plasma cells union done
# nonsmoker ann_level_4 Plasma cells common_nonsmoker done
# nonsmoker ann_level_4 Plasmacytoid DCs fridman done
# nonsmoker ann_level_4 Plasmacytoid DCs sasp2 done
# nonsmoker ann_level_4 Plasmacytoid DCs senmayo done
# nonsmoker ann_level_4 Plasmacytoid DCs cellage done
# nonsmoker ann_level_4 Plasmacytoid DCs union done
# nonsmoker ann_level_4 Plasmacytoid DCs common_nonsmoker done
# nonsmoker ann_level_4 SMG duct fridman done
# nonsmoker ann_level_4 SMG duct sasp2 done
# nonsmoker ann_level_4 SMG duct senmayo done
# nonsmoker ann_level_4 SMG duct cellage done
# nonsmoker ann_level_4 SMG duct union done
# nonsmoker ann_level_4 SMG duct common_nonsmoker done
# nonsmoker ann_level_4 SMG mucous fridman done
# nonsmoker ann_level_4 SMG mucous sasp2 done
# nonsmoker ann_level_4 SMG mucous senmayo done
# nonsmoker ann_level_4 SMG mucous cellage done
# nonsmoker ann_level_4 SMG mucous union done
# nonsmoker ann_level_4 SMG mucous common_nonsmoker done
# nonsmoker ann_level_4 SMG serous fridman done
# nonsmoker ann_level_4 SMG serous sasp2 done
# nonsmoker ann_level_4 SMG serous senmayo done
# nonsmoker ann_level_4 SMG serous cellage done
# nonsmoker ann_level_4 SMG serous union done
# nonsmoker ann_level_4 SMG serous common_nonsmoker done
# nonsmoker ann_level_4 Subpleural fibroblasts fridman done
# nonsmoker ann_level_4 Subpleural fibroblasts sasp2 done
# nonsmoker ann_level_4 Subpleural fibroblasts senmayo done
# nonsmoker ann_level_4 Subpleural fibroblasts cellage done
# nonsmoker ann_level_4 Subpleural fibroblasts union done
# nonsmoker ann_level_4 Subpleural fibroblasts common_nonsmoker done
# nonsmoker ann_level_4 Suprabasal fridman done
# nonsmoker ann_level_4 Suprabasal sasp2 done
# nonsmoker ann_level_4 Suprabasal senmayo done
# nonsmoker ann_level_4 Suprabasal cellage done
# nonsmoker ann_level_4 Suprabasal union done
# nonsmoker ann_level_4 Suprabasal common_nonsmoker done
# nonsmoker ann_level_4 T cells proliferating fridman done
# nonsmoker ann_level_4 T cells proliferating sasp2 done
# nonsmoker ann_level_4 T cells proliferating senmayo done
# nonsmoker ann_level_4 T cells proliferating cellage done
# nonsmoker ann_level_4 T cells proliferating union done
# nonsmoker ann_level_4 T cells proliferating common_nonsmoker done
# nonsmoker ann_level_4 Transitional Club-AT2 fridman done
# nonsmoker ann_level_4 Transitional Club-AT2 sasp2 done
# nonsmoker ann_level_4 Transitional Club-AT2 senmayo done
# nonsmoker ann_level_4 Transitional Club-AT2 cellage done
# nonsmoker ann_level_4 Transitional Club-AT2 union done
# nonsmoker ann_level_4 Transitional Club-AT2 common_nonsmoker done
# nonsmoker ann_level_4 Tuft fridman done
# nonsmoker ann_level_4 Tuft sasp2 done
# nonsmoker ann_level_4 Tuft senmayo done
# nonsmoker ann_level_4 Tuft cellage done
# nonsmoker ann_level_4 Tuft union done
# nonsmoker ann_level_4 Tuft common_nonsmoker done
# nonsmoker ann_level_5 AT0 fridman done
# nonsmoker ann_level_5 AT0 sasp2 done
# nonsmoker ann_level_5 AT0 senmayo done
# nonsmoker ann_level_5 AT0 cellage done
# nonsmoker ann_level_5 AT0 union done
# nonsmoker ann_level_5 AT0 common_nonsmoker done
# nonsmoker ann_level_5 Alveolar Mph CCL3+ fridman done
# nonsmoker ann_level_5 Alveolar Mph CCL3+ sasp2 done
# nonsmoker ann_level_5 Alveolar Mph CCL3+ senmayo done
# nonsmoker ann_level_5 Alveolar Mph CCL3+ cellage done
# nonsmoker ann_level_5 Alveolar Mph CCL3+ union done
# nonsmoker ann_level_5 Alveolar Mph CCL3+ common_nonsmoker done
# nonsmoker ann_level_5 Alveolar Mph MT-positive fridman done
# nonsmoker ann_level_5 Alveolar Mph MT-positive sasp2 done
# nonsmoker ann_level_5 Alveolar Mph MT-positive senmayo done
# nonsmoker ann_level_5 Alveolar Mph MT-positive cellage done
# nonsmoker ann_level_5 Alveolar Mph MT-positive union done
# nonsmoker ann_level_5 Alveolar Mph MT-positive common_nonsmoker done
# nonsmoker ann_level_5 Alveolar Mph proliferating fridman done
# nonsmoker ann_level_5 Alveolar Mph proliferating sasp2 done
# nonsmoker ann_level_5 Alveolar Mph proliferating senmayo done
# nonsmoker ann_level_5 Alveolar Mph proliferating cellage done
# nonsmoker ann_level_5 Alveolar Mph proliferating union done
# nonsmoker ann_level_5 Alveolar Mph proliferating common_nonsmoker done
# nonsmoker ann_level_5 Club (non-nasal) fridman done
# nonsmoker ann_level_5 Club (non-nasal) sasp2 done
# nonsmoker ann_level_5 Club (non-nasal) senmayo done
# nonsmoker ann_level_5 Club (non-nasal) cellage done
# nonsmoker ann_level_5 Club (non-nasal) union done
# nonsmoker ann_level_5 Club (non-nasal) common_nonsmoker done
# nonsmoker ann_level_5 Goblet (bronchial) fridman done
# nonsmoker ann_level_5 Goblet (bronchial) sasp2 done
# nonsmoker ann_level_5 Goblet (bronchial) senmayo done
# nonsmoker ann_level_5 Goblet (bronchial) cellage done
# nonsmoker ann_level_5 Goblet (bronchial) union done
# nonsmoker ann_level_5 Goblet (bronchial) common_nonsmoker done
# nonsmoker ann_level_5 Goblet (subsegmental) fridman done
# nonsmoker ann_level_5 Goblet (subsegmental) sasp2 done
# nonsmoker ann_level_5 Goblet (subsegmental) senmayo done
# nonsmoker ann_level_5 Goblet (subsegmental) cellage done
# nonsmoker ann_level_5 Goblet (subsegmental) union done
# nonsmoker ann_level_5 Goblet (subsegmental) common_nonsmoker done
# nonsmoker ann_level_5 Interstitial Mph perivascular fridman done
# nonsmoker ann_level_5 Interstitial Mph perivascular sasp2 done
# nonsmoker ann_level_5 Interstitial Mph perivascular senmayo done
# nonsmoker ann_level_5 Interstitial Mph perivascular cellage done
# nonsmoker ann_level_5 Interstitial Mph perivascular union done
# nonsmoker ann_level_5 Interstitial Mph perivascular common_nonsmoker done
# nonsmoker ann_level_5 Monocyte-derived Mph fridman done
# nonsmoker ann_level_5 Monocyte-derived Mph sasp2 done
# nonsmoker ann_level_5 Monocyte-derived Mph senmayo done
# nonsmoker ann_level_5 Monocyte-derived Mph cellage done
# nonsmoker ann_level_5 Monocyte-derived Mph union done
# nonsmoker ann_level_5 Monocyte-derived Mph common_nonsmoker done
# nonsmoker ann_level_5 Multiciliated (non-nasal) fridman done
# nonsmoker ann_level_5 Multiciliated (non-nasal) sasp2 done
# nonsmoker ann_level_5 Multiciliated (non-nasal) senmayo done
# nonsmoker ann_level_5 Multiciliated (non-nasal) cellage done
# nonsmoker ann_level_5 Multiciliated (non-nasal) union done
# nonsmoker ann_level_5 Multiciliated (non-nasal) common_nonsmoker done
# nonsmoker ann_level_5 SMG serous (bronchial) fridman done
# nonsmoker ann_level_5 SMG serous (bronchial) sasp2 done
# nonsmoker ann_level_5 SMG serous (bronchial) senmayo done
# nonsmoker ann_level_5 SMG serous (bronchial) cellage done
# nonsmoker ann_level_5 SMG serous (bronchial) union done
# nonsmoker ann_level_5 SMG serous (bronchial) common_nonsmoker done
# nonsmoker ann_level_5 pre-TB secretory fridman done
# nonsmoker ann_level_5 pre-TB secretory sasp2 done
# nonsmoker ann_level_5 pre-TB secretory senmayo done
# nonsmoker ann_level_5 pre-TB secretory cellage done
# nonsmoker ann_level_5 pre-TB secretory union done
# nonsmoker ann_level_5 pre-TB secretory common_nonsmoker done

# %%
def compute_features(expr, ages, mean_degree, var_degree, n_components, use_pca, pca_model):

    if use_pca and pca_model is None:
        pca_model = PCA(n_components=n_components, whiten=True)
        expr = pd.DataFrame(pca_model.fit_transform(expr), index = expr.index)
        expr.columns = [f"PC{i+1}" for i in range(expr.shape[1])]
    elif use_pca and pca_model is not None:
        expr = pd.DataFrame(pca_model.transform(expr), index = expr.index)
        expr.columns = [f"PC{i+1}" for i in range(expr.shape[1])]
        
    # Get each subject/individual's mean expression and polynomials of mean expressions.
    subjects = expr.index.to_list()
    expr_mean = expr.groupby(subjects).mean()
    expr_mean_poly = np.hstack([expr_mean**i for i in range(1, mean_degree+1)])
    feature_names = np.hstack([[f"{col}_mean^{deg}" for col in expr.columns] for deg in range(1,mean_degree+1)]) # Name the polynomial features
    expr_mean_poly = pd.DataFrame(
                        expr_mean_poly,
                        index = expr_mean.index,
                        columns = feature_names 
                    )
    
    if var_degree > 0:

        # Get each subject/indivisual's variances.
        expr_var = expr.groupby(subjects).var()
        expr_var.fillna(value=0,inplace=True) # This should not happen 
        expr_var_poly = np.hstack([expr_var**i for i in range(1, var_degree+1)])
        feature_names = np.hstack([[f"{col}_var^{deg}" for col in expr.columns] for deg in range(1,var_degree+1)]) # Name the polynomial features
        expr_var_poly = pd.DataFrame(
                        expr_var_poly,
                        index = expr_var.index,
                        columns = feature_names 
                    )

        # Concatenate mean and var polynomial features
        X = pd.concat([expr_mean_poly,expr_var_poly],axis = 1)
    else:
        X = expr_mean_poly
    
    # Get Y
    Y = ages.groupby(subjects).mean()
    
    return X,Y,pca_model

# %%
def tune(param, train_subjects, expr, ages, use_pca, ct):
    
    '''
    # Get Hyperparameters
    '''
    n_components = param['n_components']
    mean_degree = param['mean_degree']
    var_degree = param['var_degree']
    alpha = param['alpha']
    l1_ratio = param['l1_ratio']
    
    expr_train = expr.copy().loc[train_subjects,]
    ages_train = ages.copy().loc[train_subjects,]
    
    # Get fature matrix for training data
    X_train,Y_train,pca_model = compute_features(expr_train,
                                         ages_train,
                                         mean_degree,
                                         var_degree,
                                         n_components,
                                         use_pca,
                                         pca_model=None)
    # Center and scale the features
    Y_train = Y_train.values
    X_train = StandardScaler().fit_transform(X_train)
    #Y_train = StandardScaler().fit_transform(Y_train.reshape(-1,1)).ravel()
    
    # Model fitting
    polyreg = make_pipeline(ElasticNet(max_iter=40000, alpha=alpha, l1_ratio=l1_ratio,random_state=42))
    polyreg.fit(X_train, Y_train)
        
    # Get predicted age for training data
    pred = polyreg.predict(X_train)
    
    # Return negative R2 as loss
    return(-r2_score(Y_train, pred))

# %%
def train(expr, ages, use_pca, param_space, n_hyper_eval, ct):
    
    subjects = expr.index.unique()
        
    # Partial will freeze some arguments for tune()
    fmin_objective = partial(
                            tune,
                            train_subjects=subjects,
                            expr=expr,
                            ages=ages,
                            use_pca=use_pca,
                            ct = ct
                        )

    # Search for the best hyperparameters on training data
    param_best = fmin(fmin_objective,
                        space = param_space,
                        algo=tpe.suggest,
                        max_evals=n_hyper_eval,
                        verbose = False
                     )
    param_best = space_eval(param_space, param_best)

    # Get fature matrix for training and testing data
    X_train,Y_train,pca_model = compute_features(
                        expr.copy(),
                        ages.copy(),
                        mean_degree = param_best['mean_degree'],
                        var_degree = param_best['var_degree'],
                        n_components = param_best['n_components'],
                        use_pca = use_pca,
                        pca_model = None
                    )

    
    # Center and scale the features
    Y_train = Y_train.values
    scaler_X = StandardScaler().fit(X_train)
    scaler_Y = StandardScaler().fit(Y_train.reshape(-1,1))
    X_train = scaler_X.transform(X_train)
    Y_train = scaler_Y.transform(Y_train.reshape(-1,1)).ravel()
    
    # Use the best hyperparameters to fit a model on training data
    polyreg = make_pipeline(ElasticNet(max_iter=40000, alpha=param_best['alpha'], l1_ratio=param_best['l1_ratio'],random_state=42))
    polyreg.fit(X_train, Y_train)
    
    # Return the model itself
    #return polyreg,pca_model,param_best
    return polyreg,param_best,scaler_X,scaler_Y,pca_model

# %%
def test(expr, ages, use_pca, param_best, ct, model, scaler_X, scaler_Y, pca_model):
    
    subjects = expr.index.unique()

    # Get fature matrix for training and testing data
    X_test,Y_test,_ = compute_features(
                        expr.copy(),
                        ages.copy(),
                        mean_degree = param_best['mean_degree'],
                        var_degree = param_best['var_degree'],
                        n_components = param_best['n_components'],
                        use_pca = use_pca,
                        pca_model = pca_model
                    )
    
    # Standardize features
    Y_test = Y_test.values
    X_test = scaler_X.transform(X_test)
    Y_test = scaler_Y.transform(Y_test.reshape(-1,1)).ravel()
    
    # Use the best hyperparameters to fit a model on training data
    pred = model.predict(X_test)
    
    # Return R2 score score
    return r2_score(Y_test, pred),mean_absolute_error(Y_test, pred),Y_test*np.sqrt(scaler_Y.var_) + scaler_Y.mean_, pred*np.sqrt(scaler_Y.var_) + scaler_Y.mean_

# %% [markdown]
# ### Main analysis pipeline
# Adjust n_jobs based on number of cores and memory available in your machine

# %%
from joblib import delayed, Parallel
import warnings

def run_all(expr_train,ages_train,expr_test,ages_test,group,ct,annLevel,gene_type,use_pca,rep,donor_num_train,donor_num_test,n_hyper_eval):
    
    warnings.filterwarnings("ignore")

    # Parameter search space
    param_space = {'n_components' : hp.choice('n_components', [10]),
                 'mean_degree': hp.choice('mean_degree', [2]),
                 'var_degree': hp.choice('var_degree', [2]), 
                 'alpha': hp.choice('alpha', [0.001, 0.01, 0.1, 1, 10, 100]), 
                 'l1_ratio': hp.uniform('l1_ratio', 0.1, 1.0)
        }
    
    train_donor_num = expr_train.index.unique().shape[0] 
    test_donor_num = expr_test.index.unique().shape[0] 
    
    if train_donor_num >= 5 and test_donor_num >= 5:
        
        # Train on train and test on test lung data
        model,param_best,scaler_X,scaler_Y,pca_model = train(expr_train, ages_train, use_pca, param_space, n_hyper_eval = n_hyper_eval, ct = ct)
        r2_train,MAE_train,Y_trues,Y_preds = test(expr_test, ages_test, use_pca, param_best, ct = ct, model = model,scaler_X = scaler_X,scaler_Y=scaler_Y,pca_model=pca_model)
        Y_trues = ",".join([str(age) for age in Y_trues])
        Y_preds = ",".join([str(age) for age in Y_preds])
    else:
        r2_train = np.nan
        MAE_train = np.nan
        Y_trues = ""
        Y_preds = ""
        
    return annLevel, group, ct, gene_type, use_pca, r2_train, MAE_train,rep,donor_num_train,donor_num_test,Y_trues,Y_preds
    

res = Parallel(n_jobs = 120)(delayed(run_all)(
                                                expr_train,ages_train,
                                                expr_test,ages_test,
                                                group,ct,annLevel,gene_type,
                                                use_pca,rep,donor_num_train,donor_num_test,
                                                n_hyper_eval = 30
                                            ) for expr_train,ages_train,expr_test,ages_test,group,ct,annLevel,gene_type,use_pca,rep,donor_num_train,donor_num_test in tqdm(iterator))
# Out:
#   0%|          | 0/9360 [00:00<?, ?it/s]
#
#   1%|▏         | 120/9360 [00:14<18:56,  8.13it/s]
#
#   3%|▎         | 240/9360 [00:18<10:30, 14.46it/s]
#
#   4%|▍         | 360/9360 [00:26<10:20, 14.51it/s]
#
#   5%|▌         | 480/9360 [00:42<13:50, 10.70it/s]
#
#   6%|▋         | 600/9360 [00:57<15:21,  9.51it/s]
#
#   8%|▊         | 720/9360 [01:13<16:22,  8.80it/s]
#
#   9%|▉         | 840/9360 [01:48<24:19,  5.84it/s]
#
#  10%|█         | 960/9360 [02:00<20:54,  6.70it/s]
#
#  12%|█▏        | 1080/9360 [02:24<22:47,  6.06it/s]
#
#  13%|█▎        | 1200/9360 [03:10<31:51,  4.27it/s]
#
#  14%|█▍        | 1320/9360 [03:35<30:12,  4.44it/s]
#
#  15%|█▌        | 1440/9360 [04:01<29:18,  4.50it/s]
#
#  17%|█▋        | 1560/9360 [04:36<31:32,  4.12it/s]
#
#  18%|█▊        | 1680/9360 [06:42<1:02:17,  2.05it/s]
#
#  19%|█▉        | 1800/9360 [09:44<1:40:30,  1.25it/s]
#
#  21%|██        | 1920/9360 [09:45<1:09:27,  1.79it/s]
#
#  21%|██        | 1920/9360 [09:56<1:09:27,  1.79it/s]
#
#  22%|██▏       | 2040/9360 [14:42<2:18:31,  1.14s/it]
#
#  23%|██▎       | 2160/9360 [21:37<3:40:10,  1.83s/it]
#
#  24%|██▍       | 2280/9360 [26:08<3:51:23,  1.96s/it]
#
#  26%|██▌       | 2400/9360 [26:49<2:51:11,  1.48s/it]
#
#  27%|██▋       | 2520/9360 [28:08<2:20:13,  1.23s/it]
#
#  28%|██▊       | 2640/9360 [28:48<1:47:42,  1.04it/s]
#
#  29%|██▉       | 2760/9360 [29:27<1:24:38,  1.30it/s]
#
#  31%|███       | 2880/9360 [29:28<58:27,  1.85it/s]
#
#  31%|███       | 2880/9360 [29:46<58:27,  1.85it/s]
#
#  32%|███▏      | 3000/9360 [29:52<46:34,  2.28it/s]
#
#  33%|███▎      | 3120/9360 [30:10<36:42,  2.83it/s]
#
#  35%|███▍      | 3240/9360 [30:37<32:03,  3.18it/s]
#
#  36%|███▌      | 3360/9360 [31:34<36:15,  2.76it/s]
#
#  37%|███▋      | 3480/9360 [32:32<39:05,  2.51it/s]
#
#  38%|███▊      | 3600/9360 [33:22<38:36,  2.49it/s]
#
#  40%|███▉      | 3720/9360 [33:23<26:42,  3.52it/s]
#
#  41%|████      | 3840/9360 [33:24<18:30,  4.97it/s]
#
#  42%|████▏     | 3960/9360 [33:25<12:54,  6.97it/s]
#
#  44%|████▎     | 4080/9360 [33:25<09:00,  9.76it/s]
#
#  45%|████▍     | 4200/9360 [33:26<06:20, 13.56it/s]
#
#  46%|████▌     | 4320/9360 [33:27<04:32, 18.47it/s]
#
#  47%|████▋     | 4440/9360 [33:28<03:17, 24.91it/s]
#
#  47%|████▋     | 4440/9360 [33:46<03:17, 24.91it/s]
#
#  49%|████▊     | 4560/9360 [34:35<15:33,  5.14it/s]
#
#  50%|█████     | 4680/9360 [37:17<42:16,  1.85it/s]
#
#  51%|█████▏    | 4800/9360 [40:56<1:10:32,  1.08it/s]
#
#  53%|█████▎    | 4920/9360 [43:20<1:14:42,  1.01s/it]
#
#  54%|█████▍    | 5040/9360 [45:19<1:12:14,  1.00s/it]
#
#  55%|█████▌    | 5160/9360 [52:06<2:00:21,  1.72s/it]
#
#  56%|█████▋    | 5280/9360 [53:27<1:35:36,  1.41s/it]
#
#  58%|█████▊    | 5400/9360 [55:44<1:27:37,  1.33s/it]
#
#  59%|█████▉    | 5520/9360 [57:28<1:16:04,  1.19s/it]
#
#  60%|██████    | 5640/9360 [59:05<1:06:35,  1.07s/it]
#
#  62%|██████▏   | 5760/9360 [1:00:32<58:15,  1.03it/s]
#
#  63%|██████▎   | 5880/9360 [1:01:20<46:20,  1.25it/s]
#
#  64%|██████▍   | 6000/9360 [1:02:11<38:28,  1.46it/s]
#
#  65%|██████▌   | 6120/9360 [1:03:46<38:43,  1.39it/s]
#
#  67%|██████▋   | 6240/9360 [1:05:59<43:28,  1.20it/s]
#
#  68%|██████▊   | 6360/9360 [1:08:16<46:23,  1.08it/s]
#
#  69%|██████▉   | 6480/9360 [1:08:17<31:18,  1.53it/s]
#
#  69%|██████▉   | 6480/9360 [1:08:36<31:18,  1.53it/s]
#
#  71%|███████   | 6600/9360 [1:10:30<36:15,  1.27it/s]
#
#  72%|███████▏  | 6720/9360 [1:12:32<37:38,  1.17it/s]
#
#  73%|███████▎  | 6840/9360 [1:15:07<41:26,  1.01it/s]
#
#  74%|███████▍  | 6960/9360 [1:19:51<56:01,  1.40s/it]
#
#  76%|███████▌  | 7080/9360 [1:22:02<49:41,  1.31s/it]
#
#  77%|███████▋  | 7200/9360 [1:24:53<48:21,  1.34s/it]
#
#  78%|███████▊  | 7320/9360 [1:26:01<37:46,  1.11s/it]
#
#  79%|███████▉  | 7440/9360 [1:27:16<30:52,  1.04it/s]
#
#  81%|████████  | 7560/9360 [1:27:57<23:19,  1.29it/s]
#
#  82%|████████▏ | 7680/9360 [1:28:25<17:13,  1.63it/s]
#
#  83%|████████▎ | 7800/9360 [1:29:02<13:34,  1.92it/s]
#
#  85%|████████▍ | 7920/9360 [1:29:03<08:49,  2.72it/s]
#
#  85%|████████▍ | 7920/9360 [1:29:16<08:49,  2.72it/s]
#
#  86%|████████▌ | 8040/9360 [1:30:58<12:00,  1.83it/s]
#
#  87%|████████▋ | 8160/9360 [1:32:20<11:44,  1.70it/s]
#
#  88%|████████▊ | 8280/9360 [1:32:22<07:28,  2.41it/s]
#
#  90%|████████▉ | 8400/9360 [1:32:23<04:41,  3.41it/s]
#
#  91%|█████████ | 8520/9360 [1:32:24<02:54,  4.82it/s]
#
#  92%|█████████▏| 8640/9360 [1:32:25<01:46,  6.79it/s]
#
#  94%|█████████▎| 8760/9360 [1:32:26<01:03,  9.45it/s]
#
#  95%|█████████▍| 8880/9360 [1:32:26<00:36, 13.16it/s]
#
#  96%|█████████▌| 9000/9360 [1:32:27<00:19, 18.10it/s]
#
#  96%|█████████▌| 9000/9360 [1:32:46<00:19, 18.10it/s]
#
#  97%|█████████▋| 9120/9360 [1:33:17<00:39,  6.12it/s]
#
#  99%|█████████▊| 9240/9360 [1:33:18<00:14,  8.56it/s]
#
#  99%|█████████▊| 9240/9360 [1:33:36<00:14,  8.56it/s]
#
# 100%|██████████| 9360/9360 [1:35:33<00:00,  1.63it/s]

# %% [markdown]
# save results

# %%
to_save = pd.DataFrame(res, columns = ["ann_level","group","cell_type","gene_type","use_pca","R2","MAE","rep","Donor_num_train","Donor_num_test","true_age","pred_age"])

# %%
to_save = to_save.sort_values(by = "R2", ascending = False)

# %%
to_save.replace(to_replace="common_smoker", value="all",inplace=True)
to_save.replace(to_replace="common_nonsmoker", value="all",inplace=True)

# %%
if not os.path.isdir("results/eval"):
    os.mkdir("results/eval")    
to_save.to_csv("results/eval/performances_CD_polyEN.csv",index = None)
